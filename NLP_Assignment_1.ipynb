# %% [markdown]
# ## Assignment 1: Perform tokenization, stopword removal, stemming, and lemmatization on a sample dataset. Compare how these preprocessing steps impact the quality of text representation.

# %%
pip install PyPDF2
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import PyPDF2

# %%
f= open("climate_change_assignment_text.pdf",'rb')

# %%
pdf_reader=PyPDF2.PdfReader(f)

# %%
len(pdf_reader.pages)
# Out:
# 3

# %%
page_one=pdf_reader.pages[0]

# %%
page_one_text=page_one.extract_text()

# %% [markdown]
# ## Tokenization

# %%
import nltk

# %%
from nltk.tokenize import word_tokenize

tokens = word_tokenize(page_one_text)

# %% [markdown]
# ## Stopwords Removal

# %%
from nltk.corpus import stopwords

# %%
stop_words=set(stopwords.words('english'))

# %%
filtered_tokens = [word for word in tokens if word not in stop_words]
print(filtered_tokens)
# Out:
# ['Climate', 'Change', ':', 'An', 'Introduction', 'Climate', 'change', 'refers', 'long-term', 'changes', 'temperature', ',', 'rainfall', ',', 'overall', 'weather', 'patterns', 'across', 'Earth', '.', 'These', 'changes', 'observed', 'several', 'decades', 'recognized', 'one', 'serious', 'global', 'challenges', '.', 'While', 'natural', 'processes', 'influenced', 'climate', 'past', ',', 'scientific', 'studies', 'show', 'recent', 'climate', 'change', 'largely', 'driven', 'human', 'activities', '.', 'The', 'burning', 'fossil', 'fuels', 'coal', ',', 'oil', ',', 'natural', 'gas', 'releases', 'greenhouse', 'gases', 'atmosphere', '.', 'These', 'gases', 'trap', 'heat', 'lead', 'gradual', 'increase', 'global', 'temperatures', ',', 'phenomenon', 'known', 'global', 'warming', '.', 'Deforestation', 'industrial', 'activities', 'contribute', 'rise', 'carbon', 'dioxide', 'levels', '.', 'As', 'global', 'temperatures', 'increase', ',', 'glaciers', 'polar', 'ice', 'caps', 'melting', 'alarming', 'rate', '.
# ...

# %% [markdown]
# ## Stemming

# %%
from nltk.stem import PorterStemmer

ps = PorterStemmer()
stemmed_tokens = [ps.stem(word) for word in filtered_tokens]
print(stemmed_tokens)
# Out:
# ['climat', 'chang', ':', 'an', 'introduct', 'climat', 'chang', 'refer', 'long-term', 'chang', 'temperatur', ',', 'rainfal', ',', 'overal', 'weather', 'pattern', 'across', 'earth', '.', 'these', 'chang', 'observ', 'sever', 'decad', 'recogn', 'one', 'seriou', 'global', 'challeng', '.', 'while', 'natur', 'process', 'influenc', 'climat', 'past', ',', 'scientif', 'studi', 'show', 'recent', 'climat', 'chang', 'larg', 'driven', 'human', 'activ', '.', 'the', 'burn', 'fossil', 'fuel', 'coal', ',', 'oil', ',', 'natur', 'ga', 'releas', 'greenhous', 'gase', 'atmospher', '.', 'these', 'gase', 'trap', 'heat', 'lead', 'gradual', 'increas', 'global', 'temperatur', ',', 'phenomenon', 'known', 'global', 'warm', '.', 'deforest', 'industri', 'activ', 'contribut', 'rise', 'carbon', 'dioxid', 'level', '.', 'as', 'global', 'temperatur', 'increas', ',', 'glacier', 'polar', 'ice', 'cap', 'melt', 'alarm', 'rate', '.', 'thi', 'result', 'rise', 'sea', 'level', ',', 'threaten', 'coastal', 'region', 'low-li', 'is
# ...

# %% [markdown]
# ## Lemmatization

# %%
from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()

lemmatized_tokens = [lemmatizer.lemmatize(word) for word in filtered_tokens]

print(lemmatized_tokens)
# Out:
# ['Climate', 'Change', ':', 'An', 'Introduction', 'Climate', 'change', 'refers', 'long-term', 'change', 'temperature', ',', 'rainfall', ',', 'overall', 'weather', 'pattern', 'across', 'Earth', '.', 'These', 'change', 'observed', 'several', 'decade', 'recognized', 'one', 'serious', 'global', 'challenge', '.', 'While', 'natural', 'process', 'influenced', 'climate', 'past', ',', 'scientific', 'study', 'show', 'recent', 'climate', 'change', 'largely', 'driven', 'human', 'activity', '.', 'The', 'burning', 'fossil', 'fuel', 'coal', ',', 'oil', ',', 'natural', 'gas', 'release', 'greenhouse', 'gas', 'atmosphere', '.', 'These', 'gas', 'trap', 'heat', 'lead', 'gradual', 'increase', 'global', 'temperature', ',', 'phenomenon', 'known', 'global', 'warming', '.', 'Deforestation', 'industrial', 'activity', 'contribute', 'rise', 'carbon', 'dioxide', 'level', '.', 'As', 'global', 'temperature', 'increase', ',', 'glacier', 'polar', 'ice', 'cap', 'melting', 'alarming', 'rate', '.', 'This', 'result', 'ri
# ...
